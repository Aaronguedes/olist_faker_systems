# %%
# %sql
SELECT * FROM lakehouse.bronze.crm_customers;

# %%
# %sql
SELECT * FROM lakehouse.bronze.ecommerce_customers;

# %%
# %sql
SELECT * FROM lakehouse.bronze.ecommerce_products;

# %%
# %sql
SELECT * FROM lakehouse.bronze.ecommerce_sellers;

# %%
# %sql
SELECT * FROM lakehouse.bronze.erp_customers;

# %%
# %sql
SELECT * FROM lakehouse.bronze.erp_orders;

# %%
# %sql
SELECT * FROM lakehouse.bronze.erp_payments;

# %%
# %sql
SELECT * FROM lakehouse.bronze.loyalty_customers;
